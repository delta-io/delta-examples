# %% [markdown]
# ## Python deltalake 0.8.1 Release
#
# The 0.8.1 version of Python deltalake adds overwriting partitions. In the `write_deltalake` function you can use `mode='overwrite'` in combination with `partition_filters` to overwrite part of a Delta Lake table. This can be a single partition or multiple partitions.

# %% [markdown]
# As an example, let's say we have a table partitioned by date.

# %%
from datetime import date

import numpy as np
import numpy.random
import pandas as pd
from deltalake import DeltaTable, write_deltalake

nrows = 9
data = pd.DataFrame(
    {
        "observation_date": np.repeat(
            [date(2023, 1, 1), date(2023, 1, 2), date(2023, 1, 3)], nrows / 3
        ),
        "values": numpy.random.normal(size=nrows),
    }
)
table_path = "tables/observations"
write_deltalake(
    table_path,
    data,
    partition_by=["observation_date"],
    mode="overwrite",
)
DeltaTable(table_path).to_pandas()
# Out:
#   observation_date    values
# 0       2023-01-02 -0.363669
# 1       2023-01-02  1.821875
# 2       2023-01-02  1.648210
# 3       2023-01-03 -1.672757
# 4       2023-01-03 -1.378446
# 5       2023-01-03 -0.559470
# 6       2023-01-01 -0.190479
# 7       2023-01-01  1.431008
# 8       2023-01-01 -0.188100

# %% [markdown]
# If we have new data to replace the observations on 2023-01-03, we can overwrite the partition with new data by passing the DNF filter `[("observation_date", "=", "2023-01-03")]` to `partition_filters`.

# %%
nrows = 3
new_data = pd.DataFrame(
    {
        "observation_date": np.repeat(date(2023, 1, 3), nrows),
        "values": numpy.random.normal(size=nrows) + 10,
    }
)

write_deltalake(
    table_path,
    new_data,
    mode="overwrite",
    partition_filters=[("observation_date", "=", "2023-01-03")],
)
DeltaTable(table_path).to_pandas()
# Out:
#   observation_date     values
# 0       2023-01-02  -0.363669
# 1       2023-01-02   1.821875
# 2       2023-01-02   1.648210
# 3       2023-01-01  -0.190479
# 4       2023-01-01   1.431008
# 5       2023-01-01  -0.188100
# 6       2023-01-03   8.542938
# 7       2023-01-03   9.833954
# 8       2023-01-03  10.937024

# %% [markdown]
# Now we have the new values just in the 2023-01-01 partition.
#
# You can also use partition writing to create *new* partitions. This makes the operation [idempotent](https://en.wikipedia.org/wiki/Idempotence), which is a very useful property in data engineering. If an overwrite partition is accidentally run twice for the same partition, it won't create duplicate data. This is a property relied on in systems like Airflow.

# %% [markdown]
# To make sure the write is safe, this method will check your data to make sure it only within the partitions you are overwriting. This makes sure no one accidentally corrupts the table. For example, if we tried to save that same data for 2023-01-03 into the partition for 2023-01-04, we will get an error:

# %%
write_deltalake(
    table_path,
    new_data,
    mode="overwrite",
    partition_filters=[("observation_date", "=", "2023-01-04")],
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 write_deltalake(
#       2     table_path,
#       3     new_data,
#       4     mode="overwrite",
#       5     partition_filters=[("observation_date", "=", "2023-01-04")],
#       6 )
#
# File ~/mambaforge/envs/notebooks/lib/python3.10/site-packages/deltalake/writer.py:293, in write_deltalake(table_or_uri, data, schema, partition_by, filesystem, mode, file_options, max_open_files, max_rows_per_file, min_rows_per_group, max_rows_per_group, name, description, configuration, overwrite_schema, storage_options, partition_filters)
#     287         batch_iter = data
#     289     data = RecordBatchReader.from_batches(
#     290         schema, (validate_batch(batch) for batch in batch_iter)
#     291     )
# --> 293 ds.write_dataset(
#     294     data,
#     295     base_dir="/",
#     296     basename_template=f"{current_version + 1}-{uuid.uuid4()}-{{i}}.parquet",
#     297     format="parquet",
#     298     partitioning=partitioning,
#     299     # It will not accept a schema if using a RBR
#     300     schema=schema if not isinstance(data, RecordBatchReader) else None,
#     301     file_visitor=visitor,
#     302     existing_data_behavior="overwrite_or_ignore",
#     303     file_options=file_options,
#     304     max_open_files=max_open_files,
#     305     max_rows_per_file=max_rows_per_file,
#     306     min_rows_per_group=min_rows_per_group,
#     307     max_rows_per_group=max_rows_per_group,
#     308     filesystem=filesystem,
#     309 )
#     311 if table is None:
#     312     _write_new_deltalake(
#     313         table_uri,
#     314         schema,
#    (...)
#     321         storage_options,
#     322     )
#
# File ~/mambaforge/envs/notebooks/lib/python3.10/site-packages/pyarrow/dataset.py:998, in write_dataset(data, base_dir, basename_template, format, partitioning, partitioning_flavor, schema, filesystem, file_options, use_threads, max_partitions, max_open_files, max_rows_per_file, min_rows_per_group, max_rows_per_group, file_visitor, existing_data_behavior, create_dir)
#     995         raise ValueError("Cannot specify a schema when writing a Scanner")
#     996     scanner = data
# --> 998 _filesystemdataset_write(
#     999     scanner, base_dir, basename_template, filesystem, partitioning,
#    1000     file_options, max_partitions, file_visitor, existing_data_behavior,
#    1001     max_open_files, max_rows_per_file,
#    1002     min_rows_per_group, max_rows_per_group, create_dir
#    1003 )
#
# File ~/mambaforge/envs/notebooks/lib/python3.10/site-packages/pyarrow/_dataset.pyx:3016, in pyarrow._dataset._filesystemdataset_write()
#
# File ~/mambaforge/envs/notebooks/lib/python3.10/site-packages/deltalake/writer.py:290, in <genexpr>(.0)
#     286     else:
#     287         batch_iter = data
#     289     data = RecordBatchReader.from_batches(
# --> 290         schema, (validate_batch(batch) for batch in batch_iter)
#     291     )
#     293 ds.write_dataset(
#     294     data,
#     295     base_dir="/",
#    (...)
#     308     filesystem=filesystem,
#     309 )
#     311 if table is None:
#
# File ~/mambaforge/envs/notebooks/lib/python3.10/site-packages/deltalake/writer.py:276, in write_deltalake.<locals>.validate_batch(batch)
#     273 checker.check_batch(batch)
#     275 if mode == "overwrite" and partition_filters:
# --> 276     check_data_is_aligned_with_partition_filtering(batch)
#     278 return batch
#
# File ~/mambaforge/envs/notebooks/lib/python3.10/site-packages/deltalake/writer.py:267, in write_deltalake.<locals>.check_data_is_aligned_with_partition_filtering(batch)
#     260 if (
#     261     partition not in allowed_partitions
#     262     and partition in existed_partitions
#     263 ):
#     264     partition_repr = " ".join(
#     265         f"{key}={value}" for key, value in partition_map.items()
#     266     )
# --> 267     raise ValueError(
#     268         f"Data should be aligned with partitioning. "
#     269         f"Data contained values for partition {partition_repr}"
#     270     )
#
# ValueError: Data should be aligned with partitioning. Data contained values for partition observation_date=2023-01-03

# %% [markdown]
# You can also overwrite more than one partition at a time, since `partition_filters` supports inequality conditions.

# %%
nrows = 12
new_data = pd.DataFrame(
    {
        "observation_date": np.repeat(
            [date(2023, 1, 2), date(2023, 1, 3), date(2023, 1, 4)], nrows / 3
        ),
        "values": numpy.random.normal(size=nrows) - 5,
    }
)

write_deltalake(
    table_path,
    new_data,
    mode="overwrite",
    partition_filters=[("observation_date", ">=", "2023-01-02")],
)
DeltaTable(table_path).to_pandas()
# Out:
#    observation_date    values
# 0        2023-01-01 -0.190479
# 1        2023-01-01  1.431008
# 2        2023-01-01 -0.188100
# 3        2023-01-02 -5.516889
# 4        2023-01-02 -5.271391
# 5        2023-01-02 -6.383807
# 6        2023-01-02 -3.205016
# 7        2023-01-04 -4.892187
# 8        2023-01-04 -6.186804
# 9        2023-01-04 -6.719393
# 10       2023-01-04 -4.467193
# 11       2023-01-03 -6.571248
# 12       2023-01-03 -2.436545
# 13       2023-01-03 -4.061226
# 14       2023-01-03 -3.851402

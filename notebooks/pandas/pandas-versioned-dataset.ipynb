# %% [markdown]
# # Version pandas with deltalake
#
# This notebook works with the `pandas-deltalake` environment.

# %%
import os

import pandas as pd
from deltalake import DeltaTable
from deltalake.writer import write_deltalake

# %% [markdown]
# ## Create Delta Lake

# %%
df = pd.DataFrame({"x": [1, 2, 3]})

# %%
df
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
os.makedirs("tmp/some_delta_lake", exist_ok=True)

# %%
write_deltalake("tmp/some_delta_lake", df)

# %%
dt = DeltaTable("tmp/some_delta_lake")

# %%
dt.to_pandas()
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
# !tree tmp/some_delta_lake
# Out:
# tmp/some_delta_lake
# ├── 0-7aa8fde5-a55b-434a-b436-a8c8180f446e-0.parquet
# └── _delta_log
#     └── 00000000000000000000.json
#
# 1 directory, 2 files

# %%
# !jq . tmp/some_delta_lake/_delta_log/00000000000000000000.json
# Out:
# {
#   "commitInfo": {
#     "delta-rs": "0.4.1",
#     "timestamp": 1680730058520
#   }
# }
# {
#   "protocol": {
#     "minReaderVersion": 1,
#     "minWriterVersion": 1
#   }
# }
# {
#   "metaData": {
#     "id": "bf7e6bcd-37de-4a39-aa49-82d211b92611",
#     "name": null,
#     "description": null,
#     "format": {
#       "provider": "parquet",
#       "options": {}
#     },
#     "schemaString": "{\"type\":\"struct\",\"fields\":[{\"name\":\"x\",\"type\":\"long\",\"nullable\":true,\"metadata\":{}}]}",
#     "partitionColumns": [],
#     "createdTime": 1680730058513,
#     "configuration": {}
#   }
# }
# {
#   "add": {
#     "path": "0-7aa8fde5-a55b-434a-b436-a8c8180f446e-0.parquet",
#     "size": 1652,
#     "partitionValues": {},
#     "modificationTime": 1680730058,
#     "dataChange": true,
#     "stats": "{\"numRecords\": 3, \"minValues\": {\"x\": 1}, \"maxValues\": {\"x\": 3}, \"nullCount\": {\"x\": 0}}",
#     "tags": null
#   }
# }

# %% [markdown]
# ## Append to Delta Lake

# %%
df2 = pd.DataFrame({"x": [8, 9, 10]})

# %%
write_deltalake("tmp/some_delta_lake", df2, mode="append")

# %%
# !tree tmp/some_delta_lake
# Out:
# tmp/some_delta_lake
# ├── 0-7aa8fde5-a55b-434a-b436-a8c8180f446e-0.parquet
# ├── 1-f416093b-56cf-4991-b54b-919721a0ced4-0.parquet
# └── _delta_log
#     ├── 00000000000000000000.json
#     └── 00000000000000000001.json
#
# 1 directory, 4 files

# %%
DeltaTable("tmp/some_delta_lake").to_pandas()
# Out:
#     x
# 0   1
# 1   2
# 2   3
# 3   8
# 4   9
# 5  10

# %% [markdown]
# ## pandas time travel

# %%
dt = DeltaTable("tmp/some_delta_lake", version=0)

# %%
dt.to_pandas()
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
DeltaTable("tmp/some_delta_lake").to_pandas()
# Out:
#     x
# 0   1
# 1   2
# 2   3
# 3   8
# 4   9
# 5  10

# %% [markdown]
# ## Overwrite Delta Lake

# %%
df3 = pd.DataFrame({"x": [55, 66, 77]})

# %%
df3
# Out:
#     x
# 0  55
# 1  66
# 2  77

# %%
write_deltalake("tmp/some_delta_lake", df3, mode="overwrite")

# %%
# !tree tmp/some_delta_lake
# Out:
# tmp/some_delta_lake
# ├── 0-7aa8fde5-a55b-434a-b436-a8c8180f446e-0.parquet
# ├── 1-f416093b-56cf-4991-b54b-919721a0ced4-0.parquet
# ├── 2-cb17f8fb-a680-46a5-a55f-f3da52ecf7df-0.parquet
# └── _delta_log
#     ├── 00000000000000000000.json
#     ├── 00000000000000000001.json
#     └── 00000000000000000002.json
#
# 1 directory, 6 files

# %%
DeltaTable("tmp/some_delta_lake").to_pandas()
# Out:
#     x
# 0  55
# 1  66
# 2  77

# %% [markdown]
# ## Confirm other versions are still accessible

# %%
DeltaTable("tmp/some_delta_lake", version=0).to_pandas()
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
DeltaTable("tmp/some_delta_lake", version=1).to_pandas()
# Out:
#     x
# 0   1
# 1   2
# 2   3
# 3   8
# 4   9
# 5  10

# %% [markdown]
# ## Schema enforcement prevents bad appends

# %%
df4 = pd.DataFrame({"y": [111, 222]})

# %%
write_deltalake("tmp/some_delta_lake", df4, mode="append")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 write_deltalake("tmp/some_delta_lake", df4, mode="append")
#
# File ~/opt/miniconda3/envs/pandas-deltalake/lib/python3.9/site-packages/deltalake/writer.py:164, in write_deltalake(table_or_uri, data, schema, partition_by, filesystem, mode, file_options, max_open_files, max_rows_per_file, min_rows_per_group, max_rows_per_group, name, description, configuration, overwrite_schema)
#     160 if table:  # already exists
#     161     if schema != table.schema().to_pyarrow() and not (
#     162         mode == "overwrite" and overwrite_schema
#     163     ):
# --> 164         raise ValueError(
#     165             "Schema of data does not match table schema\n"
#     166             f"Table schema:\n{schema}\nData Schema:\n{table.schema().to_pyarrow()}"
#     167         )
#     169     if mode == "error":
#     170         raise AssertionError("DeltaTable already exists.")
#
# ValueError: Schema of data does not match table schema
# Table schema:
# y: int64
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 357
# Data Schema:
# x: int64

# %% [markdown]
# ## Cleanup

# %%
# !rm -rf tmp

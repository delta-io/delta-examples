# %% [markdown]
# # Delta tables with ArrayType columns

# %%
import delta
import pyspark
from delta import configure_spark_with_delta_pip

# %%
builder = (
    pyspark.sql.SparkSession.builder.appName("MyApp")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config(
        "spark.sql.catalog.spark_catalog",
        "org.apache.spark.sql.delta.catalog.DeltaCatalog",
    )
)

# %%
spark = configure_spark_with_delta_pip(builder).getOrCreate()
# Out:
# :: loading settings :: url = jar:file:/Users/matthew.powers/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/matthew.powers/.ivy2/cache
# The jars for the packages stored in: /Users/matthew.powers/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-6d3acb09-87d3-4d59-9229-01eb4e097136;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 103ms :: artifacts dl 5ms
# 	:: modules in use:
# 	io.delta#delta-core_2.12;2.4.0 from central in [default]
# 	io.delta#delta-storage;2.4.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-6d3acb09-87d3-4d59-9229-01eb4e097136
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/3ms)
# 23/07/21 12:57:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df = spark.createDataFrame([("abc", [1, None]), ("cd", [3, 4])], ["id", "numbers"])

# %%
df.show()
# Out:
# +---+---------+
# | id|  numbers|
# +---+---------+
# |abc|[1, null]|
# | cd|   [3, 4]|
# +---+---------+

# %%
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- numbers: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
df.write.format("delta").save("tmp/some_delta_lake")
# Out:
# 23/07/21 12:59:45 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %% [markdown]
# ## Nested null values

# %%
df2 = spark.createDataFrame(
    [("abc", [1, [None, 3]]), ("cd", [3, [4, 5]])], ["id", "numbers"]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/types.py:1573, in _infer_schema(row, names, infer_dict_as_struct, infer_array_from_first_element, prefer_timestamp_ntz)
#    1569 try:
#    1570     fields.append(
#    1571         StructField(
#    1572             k,
# -> 1573             _infer_type(
#    1574                 v,
#    1575                 infer_dict_as_struct,
#    1576                 infer_array_from_first_element,
#    1577                 prefer_timestamp_ntz,
#    1578             ),
#    1579             True,
#    1580         )
#    1581     )
#    1582 except TypeError as e:
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/types.py:1514, in _infer_type(obj, infer_dict_as_struct, infer_array_from_first_element, prefer_timestamp_ntz)
#    1512     else:
#    1513         return ArrayType(
# -> 1514             reduce(
#    1515                 _merge_type,
#    1516                 (_infer_type(v, infer_dict_as_struct, prefer_timestamp_ntz) for v in obj),
#    1517             ),
#    1518             True,
#    1519         )
#    1520 return ArrayType(NullType(), True)
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/types.py:1654, in _merge_type(a, b, name)
#    1652 elif type(a) is not type(b):
#    1653     # TODO: type cast (such as int -> long)
# -> 1654     raise TypeError(new_msg("Can not merge type %s and %s" % (type(a), type(b))))
#    1656 # same type
#
# TypeError: Can not merge type <class 'pyspark.sql.types.LongType'> and <class 'pyspark.sql.types.ArrayType'>
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df2 = spark.createDataFrame(
#       2     [("abc", [1, [None, 3]]), ("cd", [3, [4, 5]])], ["id", "numbers"]
#       3 )
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/session.py:1276, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1271 if has_pandas and isinstance(data, pd.DataFrame):
#    1272     # Create a DataFrame from pandas DataFrame.
#    1273     return super(SparkSession, self).createDataFrame(  # type: ignore[call-overload]
#    1274         data, schema, samplingRatio, verifySchema
#    1275     )
# -> 1276 return self._create_dataframe(
#    1277     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#    1278 )
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/session.py:1318, in SparkSession._create_dataframe(self, data, schema, samplingRatio, verifySchema)
#    1316     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#    1317 else:
# -> 1318     rdd, struct = self._createFromLocal(map(prepare, data), schema)
#    1319 assert self._jvm is not None
#    1320 jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/session.py:962, in SparkSession._createFromLocal(self, data, schema)
#     959     data = list(data)
#     961 if schema is None or isinstance(schema, (list, tuple)):
# --> 962     struct = self._inferSchemaFromList(data, names=schema)
#     963     converter = _create_converter(struct)
#     964     tupled_data: Iterable[Tuple] = map(converter, data)
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/session.py:836, in SparkSession._inferSchemaFromList(self, data, names)
#     834 infer_array_from_first_element = self._jconf.legacyInferArrayTypeFromFirstElement()
#     835 prefer_timestamp_ntz = is_timestamp_ntz_preferred()
# --> 836 schema = reduce(
#     837     _merge_type,
#     838     (
#     839         _infer_schema(
#     840             row,
#     841             names,
#     842             infer_dict_as_struct=infer_dict_as_struct,
#     843             infer_array_from_first_element=infer_array_from_first_element,
#     844             prefer_timestamp_ntz=prefer_timestamp_ntz,
#     845         )
#     846         for row in data
#     847     ),
#     848 )
#     849 if _has_nulltype(schema):
#     850     raise ValueError("Some of types cannot be determined after inferring")
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/session.py:839, in <genexpr>(.0)
#     834 infer_array_from_first_element = self._jconf.legacyInferArrayTypeFromFirstElement()
#     835 prefer_timestamp_ntz = is_timestamp_ntz_preferred()
#     836 schema = reduce(
#     837     _merge_type,
#     838     (
# --> 839         _infer_schema(
#     840             row,
#     841             names,
#     842             infer_dict_as_struct=infer_dict_as_struct,
#     843             infer_array_from_first_element=infer_array_from_first_element,
#     844             prefer_timestamp_ntz=prefer_timestamp_ntz,
#     845         )
#     846         for row in data
#     847     ),
#     848 )
#     849 if _has_nulltype(schema):
#     850     raise ValueError("Some of types cannot be determined after inferring")
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/types.py:1583, in _infer_schema(row, names, infer_dict_as_struct, infer_array_from_first_element, prefer_timestamp_ntz)
#    1570         fields.append(
#    1571             StructField(
#    1572                 k,
#    (...)
#    1580             )
#    1581         )
#    1582     except TypeError as e:
# -> 1583         raise TypeError("Unable to infer the type of the field {}.".format(k)) from e
#    1584 return StructType(fields)
#
# TypeError: Unable to infer the type of the field numbers.

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import col

# %%
data2 = [
    ("James", "", "Smith", "36636", "M", 3000, [[1, None], [2, 2]]),
    ("Michael", "Rose", "", "40288", "M", 4000, [[3, 3], [4, 4]]),
]

schema = StructType(
    [
        StructField("firstname", StringType(), True),
        StructField("middlename", StringType(), True),
        StructField("lastname", StringType(), True),
        StructField("id", StringType(), True),
        StructField("gender", StringType(), True),
        StructField("salary", IntegerType(), True),
        StructField("nums", ArrayType(ArrayType(IntegerType(), True), True), True),
    ]
)

# %%
df = spark.createDataFrame(data=data2, schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- firstname: string (nullable = true)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- nums: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: integer (containsNull = true)
#
# +---------+----------+--------+-----+------+------+-------------------+
# |firstname|middlename|lastname|id   |gender|salary|nums               |
# +---------+----------+--------+-----+------+------+-------------------+
# |James    |          |Smith   |36636|M     |3000  |[[1, null], [2, 2]]|
# |Michael  |Rose      |        |40288|M     |4000  |[[3, 3], [4, 4]]   |
# +---------+----------+--------+-----+------+------+-------------------+

# %%
df.write.format("delta").save("tmp/some_delta_lake2")

# %%
data2 = [
    ("James", "", "Smith", "36636", "M", 3000, [[1, None], [2, 2]], None),
    ("Michael", "Rose", "", "40288", "M", 4000, [[3, 3], [4, 4]], None),
]

schema = StructType(
    [
        StructField("firstname", StringType(), True),
        StructField("middlename", StringType(), True),
        StructField("lastname", StringType(), True),
        StructField("id", StringType(), True),
        StructField("gender", StringType(), True),
        StructField("salary", IntegerType(), True),
        StructField("nums", ArrayType(ArrayType(IntegerType(), True), True), True),
        StructField("whatever", NullType(), True),
    ]
)

# %%
df = spark.createDataFrame(data=data2, schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- firstname: string (nullable = true)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- nums: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: integer (containsNull = true)
#  |-- whatever: void (nullable = true)
#
# +---------+----------+--------+-----+------+------+-------------------+--------+
# |firstname|middlename|lastname|id   |gender|salary|nums               |whatever|
# +---------+----------+--------+-----+------+------+-------------------+--------+
# |James    |          |Smith   |36636|M     |3000  |[[1, null], [2, 2]]|null    |
# |Michael  |Rose      |        |40288|M     |4000  |[[3, 3], [4, 4]]   |null    |
# +---------+----------+--------+-----+------+------+-------------------+--------+

# %%
df.write.format("delta").save("tmp/some_delta_lake3")

# %%
data2 = [
    ("James", "", "Smith", "36636", "M", 3000, [[None, None], [None, None]], None),
    ("Michael", "Rose", "", "40288", "M", 4000, [[None, None], [None, None]], None),
]

schema = StructType(
    [
        StructField("firstname", StringType(), True),
        StructField("middlename", StringType(), True),
        StructField("lastname", StringType(), True),
        StructField("id", StringType(), True),
        StructField("gender", StringType(), True),
        StructField("salary", IntegerType(), True),
        StructField("nums", ArrayType(ArrayType(NullType(), True), True), True),
        StructField("whatever", NullType(), True),
    ]
)

# %%
df = spark.createDataFrame(data=data2, schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- firstname: string (nullable = true)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- nums: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: void (containsNull = true)
#  |-- whatever: void (nullable = true)
#
# +---------+----------+--------+-----+------+------+----------------------------+--------+
# |firstname|middlename|lastname|id   |gender|salary|nums                        |whatever|
# +---------+----------+--------+-----+------+------+----------------------------+--------+
# |James    |          |Smith   |36636|M     |3000  |[[null, null], [null, null]]|null    |
# |Michael  |Rose      |        |40288|M     |4000  |[[null, null], [null, null]]|null    |
# +---------+----------+--------+-----+------+------+----------------------------+--------+

# %%
df.write.format("delta").save("tmp/some_delta_lake4")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.write.format("delta").save("tmp/some_delta_lake4")
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/readwriter.py:1398, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#    1396     self._jwrite.save()
#    1397 else:
# -> 1398     self._jwrite.save(path)
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/errors/exceptions/captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# AnalysisException:  Found nested NullType in column nums which is of ArrayType. Delta doesn't support writing NullType in complex types.

# %%
desired_type = StructField("nums", ArrayType(ArrayType(IntegerType(), True), True), True)

# %%
df = df.withColumn("nums", col("nums").cast(desired_type))
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df = df.withColumn("nums", col("nums").cast(desired_type))
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/sql/column.py:1193, in Column.cast(self, dataType)
#    1190     from pyspark.sql import SparkSession
#    1192     spark = SparkSession._getActiveSessionOrCreate()
# -> 1193     jdt = spark._jsparkSession.parseDataType(dataType.json())
#    1194     jc = self._jc.cast(jdt)
#    1195 else:
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/opt/miniconda3/envs/pyspark-340-delta-240/lib/python3.9/site-packages/pyspark/errors/exceptions/captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# IllegalArgumentException: Failed to convert the JSON string '{"metadata":{},"name":"nums","nullable":true,"type":{"containsNull":true,"elementType":{"containsNull":true,"elementType":"integer","type":"array"},"type":"array"}}' to a data type.

# %%
df.printSchema()
# Out:
# root
#  |-- firstname: string (nullable = true)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- nums: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: void (containsNull = true)
#  |-- whatever: void (nullable = true)

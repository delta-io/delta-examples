# %% [markdown]
# # Mage + Delta Lake
#
# This notebook highlights Delta Lake features that are useful for Mage users.

# %%
import pandas as pd
from deltalake import DeltaTable
from deltalake.writer import write_deltalake

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/mage-ai/datasets/master/battle_history.csv",
)

# %%
planets = [
    "Gaia",
    "Kamigawa\u200e\u200e",
    "Eos",
    "Ravnica\u200e\u200e",
    "Aiur",
    "Korhal",
]

# %%
df.query("`planet` == 'Kamigawa\u200e\u200e'")
# Out:
#      enemy_unit_type  odds_of_victory      planet  population  size_of_force  \
# 2              drone         0.600266  Kamigawa‎‎         3.4          61000
# 6        dreadnought         0.868513  Kamigawa‎‎         3.4          94000
# 7               tank         0.709135  Kamigawa‎‎         3.4          70000
# 10             scout         0.207542  Kamigawa‎‎         3.4          29000
# 19        battleship         0.235602  Kamigawa‎‎         3.4          81000
# ...              ...              ...         ...         ...            ...
# 9968           drone         0.340780  Kamigawa‎‎         3.4          78000
# 9975          zealot         0.569718  Kamigawa‎‎         3.4          65000
# 9983          zealot         0.007990  Kamigawa‎‎         3.4           2000
# 9984        overlord         0.174568  Kamigawa‎‎         3.4          91000
# 9988           drone         0.893971  Kamigawa‎‎         3.4          58000
#
#          universe
# 2     Dominaria‎‎
# 6     Dominaria‎‎
# 7     Dominaria‎‎
# 10    Dominaria‎‎
# 19    Dominaria‎‎
# ...           ...
# 9968  Dominaria‎‎
# 9975  Dominaria‎‎
# 9983  Dominaria‎‎
# 9984  Dominaria‎‎
# 9988  Dominaria‎‎
#
# [1600 rows x 6 columns]

# %%
for planet in planets:
    planet_df = df.query(f"`planet` == '{planet}'")
    write_deltalake(
        "tmp/battle_history",
        data=planet_df,
        mode="append",
    )

# %%
dt = DeltaTable("tmp/battle_history")

# %%
df = dt.to_pandas()

# %%
df.head()
# Out:
#   enemy_unit_type  odds_of_victory planet  population  size_of_force  \
# 0           drone         0.957991   Gaia         6.7           1000
# 1          zealot         0.581632   Gaia         6.7          15000
# 2           scout         0.050675   Gaia         6.7          10000
# 3          zealot         0.422055   Gaia         6.7          75000
# 4      battleship         0.609103   Gaia         6.7          44000
#
#    universe  __index_level_0__
# 0  Mirrodin                  0
# 1  Mirrodin                  1
# 2  Mirrodin                 15
# 3  Mirrodin                 16
# 4  Mirrodin                 18

# %%
df
# Out:
#      enemy_unit_type  odds_of_victory  planet  population  size_of_force  \
# 0              drone         0.957991    Gaia         6.7           1000
# 1             zealot         0.581632    Gaia         6.7          15000
# 2              scout         0.050675    Gaia         6.7          10000
# 3             zealot         0.422055    Gaia         6.7          75000
# 4         battleship         0.609103    Gaia         6.7          44000
# ...              ...              ...     ...         ...            ...
# 9995           mecha         0.366808  Korhal         6.7          87000
# 9996           mecha         0.030586  Korhal         6.7          37000
# 9997           mecha         0.857502  Korhal         6.7          89000
# 9998      battleship         0.264858  Korhal         6.7          94000
# 9999        overlord         0.784461  Korhal         6.7          54000
#
#         universe  __index_level_0__
# 0       Mirrodin                  0
# 1       Mirrodin                  1
# 2       Mirrodin                 15
# 3       Mirrodin                 16
# 4       Mirrodin                 18
# ...          ...                ...
# 9995  Zendikar‎‎               9966
# 9996  Zendikar‎‎               9969
# 9997  Zendikar‎‎               9971
# 9998  Zendikar‎‎               9974
# 9999  Zendikar‎‎               9990
#
# [10000 rows x 7 columns]

# %% [markdown]
# ## Time travel with versioned data

# %%
# Version 0 only contains data from Gaia
DeltaTable("tmp/battle_history", version=0).to_pandas()
# Out:
#      enemy_unit_type  odds_of_victory planet  population  size_of_force  \
# 0              drone         0.957991   Gaia         6.7           1000
# 1             zealot         0.581632   Gaia         6.7          15000
# 2              scout         0.050675   Gaia         6.7          10000
# 3             zealot         0.422055   Gaia         6.7          75000
# 4         battleship         0.609103   Gaia         6.7          44000
# ...              ...              ...    ...         ...            ...
# 1728           mecha         0.842349   Gaia         6.7          49000
# 1729      battleship         0.997295   Gaia         6.7          42000
# 1730          zealot         0.226190   Gaia         6.7          84000
# 1731        overlord         0.320292   Gaia         6.7          65000
# 1732           scout         0.448422   Gaia         6.7          58000
#
#       universe  __index_level_0__
# 0     Mirrodin                  0
# 1     Mirrodin                  1
# 2     Mirrodin                 15
# 3     Mirrodin                 16
# 4     Mirrodin                 18
# ...        ...                ...
# 1728  Mirrodin               9958
# 1729  Mirrodin               9982
# 1730  Mirrodin               9991
# 1731  Mirrodin               9994
# 1732  Mirrodin               9996
#
# [1733 rows x 7 columns]

# %%
# Latest version contains data from all planets
DeltaTable("tmp/battle_history").to_pandas()
# Out:
#      enemy_unit_type  odds_of_victory  planet  population  size_of_force  \
# 0              drone         0.957991    Gaia         6.7           1000
# 1             zealot         0.581632    Gaia         6.7          15000
# 2              scout         0.050675    Gaia         6.7          10000
# 3             zealot         0.422055    Gaia         6.7          75000
# 4         battleship         0.609103    Gaia         6.7          44000
# ...              ...              ...     ...         ...            ...
# 9995           mecha         0.366808  Korhal         6.7          87000
# 9996           mecha         0.030586  Korhal         6.7          37000
# 9997           mecha         0.857502  Korhal         6.7          89000
# 9998      battleship         0.264858  Korhal         6.7          94000
# 9999        overlord         0.784461  Korhal         6.7          54000
#
#         universe  __index_level_0__
# 0       Mirrodin                  0
# 1       Mirrodin                  1
# 2       Mirrodin                 15
# 3       Mirrodin                 16
# 4       Mirrodin                 18
# ...          ...                ...
# 9995  Zendikar‎‎               9966
# 9996  Zendikar‎‎               9969
# 9997  Zendikar‎‎               9971
# 9998  Zendikar‎‎               9974
# 9999  Zendikar‎‎               9990
#
# [10000 rows x 7 columns]

# %% [markdown]
# ## Make a partitioned Delta table

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/mage-ai/datasets/master/battle_history.csv",
)

# %%
for planet in planets:
    planet_df = df.query(f"`planet` == '{planet}'")
    write_deltalake(
        "tmp/battle_history_partitioned",
        data=planet_df,
        mode="append",
        partition_by=["planet"],
    )

# %%
# !tree tmp/battle_history_partitioned
# Out:
# tmp/battle_history_partitioned
# ├── _delta_log
# │   ├── 00000000000000000000.json
# │   ├── 00000000000000000001.json
# │   ├── 00000000000000000002.json
# │   ├── 00000000000000000003.json
# │   ├── 00000000000000000004.json
# │   └── 00000000000000000005.json
# ├── planet=Aiur
# │   └── 4-67b6d6f5-9753-4438-b9cf-dd3f84dee467-0.parquet
# ├── planet=Eos
# │   └── 2-887d613f-974a-444a-a327-374296a6c70c-0.parquet
# ├── planet=Gaia
# │   └── 0-34797246-8733-446f-b54e-16b7034abd1e-0.parquet
# ├── planet=Kamigawa%25E2%2580%258E%25E2%2580%258E
# │   └── 1-d406fd6f-f852-4f34-8307-14307b7642f8-0.parquet
# ├── planet=Korhal
# │   └── 5-545dfd2d-8ac7-43a4-9da7-1c6451593225-0.parquet
# └── planet=Ravnica%25E2%2580%258E%25E2%2580%258E
#     └── 3-0c33c5fe-054f-47dc-a3f4-37a7859e4504-0.parquet
#
# 7 directories, 12 files

# %% [markdown]
# ## Filtering by partitioning allows for file skipping, which is faster

# %%
# %%time

df = DeltaTable("tmp/battle_history").to_pandas()
df.query("planet == 'Gaia'")["enemy_unit_type"].unique()
# Out:
# CPU times: user 19.1 ms, sys: 11.7 ms, total: 30.8 ms
# Wall time: 19.6 ms
# array(['drone', 'zealot', 'scout', 'battleship', 'dreadnought',
#        'overlord', 'mecha', 'negator', 'tank'], dtype=object)

# %%
# %%time

df = DeltaTable("tmp/battle_history_partitioned").to_pandas(partitions=[("planet", "=", "Gaia")])
df.query("planet == 'Gaia'")["enemy_unit_type"].unique()
# Out:
# CPU times: user 9.5 ms, sys: 6.73 ms, total: 16.2 ms
# Wall time: 12.5 ms
# array(['drone', 'zealot', 'scout', 'battleship', 'dreadnought',
#        'overlord', 'mecha', 'negator', 'tank'], dtype=object)

# %% [markdown]
# ## Schema enforcement
#
# You can not append DataFrames with different schemas by default.  This saves you from corrupting your data.

# %%
df = pd.DataFrame({"num": [1, 2, 3], "letter": ["a", "b", "c"]})

# %%
df
# Out:
#    num letter
# 0    1      a
# 1    2      b
# 2    3      c

# %%
write_deltalake("tmp/battle_history", df, mode="append")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 write_deltalake("tmp/battle_history", df, mode="append")
#
# File ~/opt/miniconda3/envs/deltalake-090/lib/python3.9/site-packages/deltalake/writer.py:180, in write_deltalake(table_or_uri, data, schema, partition_by, filesystem, mode, file_options, max_partitions, max_open_files, max_rows_per_file, min_rows_per_group, max_rows_per_group, name, description, configuration, overwrite_schema, storage_options, partition_filters)
#     176 if table:  # already exists
#     177     if schema != table.schema().to_pyarrow() and not (
#     178         mode == "overwrite" and overwrite_schema
#     179     ):
# --> 180         raise ValueError(
#     181             "Schema of data does not match table schema\n"
#     182             f"Table schema:\n{schema}\nData Schema:\n{table.schema().to_pyarrow()}"
#     183         )
#     185     if mode == "error":
#     186         raise AssertionError("DeltaTable already exists.")
#
# ValueError: Schema of data does not match table schema
# Table schema:
# num: int64
# letter: string
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 474
# Data Schema:
# enemy_unit_type: string
# odds_of_victory: double
# planet: string
# population: double
# size_of_force: int64
# universe: string

# %% [markdown]
# ## Other features
#
# * small file compaction with OPTIMIZE
# * VACUUM command

# %%
write_deltalake(
    "tmp/battle_history_partitioned",
    data=planet_df,
    mode="append",
    allow_schema_evolution=True,
)

deltaTable.update(condition="gender = 'F'", set={"gender": "'Female'"})

deltaTable.delete("birthDate < '1955-01-01'")

# %%
(
    DeltaTable.create(spark)
    .tableName("default.people10m")
    .addColumn("id", "INT")
    .addColumn("firstName", "STRING")
    .addColumn("middleName", "STRING")
    .addColumn("lastName", "STRING", comment="surname")
    .addColumn("gender", "STRING")
    .addColumn("birthDate", "TIMESTAMP")
    .addColumn("dateOfBirth", DateType(), generatedAlwaysAs="CAST(birthDate AS DATE)")
    .partitionedBy("gender")
    .execute()
)

deltaTable = DeltaTable.convertToDelta(spark, "parquet.`<path-to-table>`")

ALTER TABLE table_name ALTER [COLUMN] col_name (COMMENT col_comment | FIRST | AFTER colA_name)
